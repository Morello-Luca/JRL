# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib as mpl
from matplotlib import font_manager

# %%
df = pd.read_csv("4.csv", sep=";")

np = pd.read_csv("3.csv", sep=";")
# Out:
# /tmp/ipykernel_313239/2683399170.py:3: DtypeWarning: Columns (75,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   np = pd.read_csv("3.csv", sep=";")

# %%
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")
# Out:
# 1. ContactForce_Reference_Left_cx
# 2. ContactForce_Reference_Left_cy
# 3. ContactForce_Reference_Left_cz
# 4. ContactForce_Reference_Left_fx
# 5. ContactForce_Reference_Left_fy
# 6. ContactForce_Reference_Left_fz
# 7. ContactForce_Reference_Right_cx
# 8. ContactForce_Reference_Right_cy
# 9. ContactForce_Reference_Right_cz
# 10. ContactForce_Reference_Right_fx
# 11. ContactForce_Reference_Right_fy
# 12. ContactForce_Reference_Right_fz
# 13. CurrentState
# 14. Default_angularAcceleration_x
# 15. Default_angularAcceleration_y
# 16. Default_angularAcceleration_z
# 17. Default_angularVelocity_x
# 18. Default_angularVelocity_y
# 19. Default_angularVelocity_z
# 20. Default_linearAcceleration_x
# 21. Default_linearAcceleration_y
# 22. Default_linearAcceleration_z
# 23. Default_linearVelocity_x
# 24. Default_linearVelocity_y
# 25. Default_linearVelocity_z
# 26. Default_orientation_w
# 27. Default_orientation_x
# 28. Default_orientation_y
# 29. Default_orientation_z
# 30. Default_position_x
# 31. Default_position_y
# 32. Default_position_z
# 33. EEForceSensor_cx
# 34. EEForceSensor_cy
# 35. EEForceSensor_cz
# 36. EEForceSensor_fx
# 37. EEForceSensor_fy
# 38. EEForceSensor_fz
# 39. EndEffectorsTajectory_LeftArm_ActualTranslation_x
# 40. EndEffectorsTajectory_LeftArm_ActualTranslation_y
# 41. EndEffectorsTajectory_LeftArm_ActualTranslation_z
# 42. EndEffectorsTajectory_LeftArm_TargetTranslation_qw
# 43. EndEffectorsTajectory_LeftArm_TargetTranslation_qx
# 44. EndEffectorsTajectory_LeftArm_TargetTranslation_qy
# 45. EndEffectorsTajectory_LeftArm_TargetTranslation_qz
# 46. EndEffectorsTajectory_LeftArm_TargetTranslation_tx
# 47. EndEffectorsTajectory_LeftArm_TargetTranslation_ty
# 48. EndEffectorsTajectory_LeftArm_TargetTranslation_tz
# 49. EndEffectorsTajectory_RightArm_ActualTranslation_x
# 50. EndEffectorsTajectory_RightArm_ActualTranslation_y
# 51. EndEffectorsTajectory_RightArm_ActualTranslation_z
# 52. EndEffectorsTajectory_RightArm_TargetTranslation_qw
# 53. EndEffectorsTajectory_RightArm_TargetTranslation_qx
# 54. EndEffectorsTajectory_RightArm_TargetTranslation_qy
# 55. EndEffectorsTajectory_RightArm_TargetTranslation_qz
# 56. EndEffectorsTajectory_RightArm_TargetTranslation_tx
# 57. EndEffectorsTajectory_RightArm_TargetTranslation_ty
# 58. EndEffectorsTajectory_RightArm_TargetTranslation_tz
# 59. EndEffectorsTajectory_Zerror_left
# 60. EndEffectorsTajectory_Zerror_right
# 61. Filters_AlphaBeta_Balanced_derivative
# 62. Filters_AlphaBeta_Balanced_state
# 63. Filters_AlphaBeta_Fast_derivative
# 64. Filters_AlphaBeta_Fast_state
# 65. Filters_AlphaBeta_Smooth_derivative
# 66. Filters_AlphaBeta_Smooth_state
# 67. Filters_LowPass_High
# 68. Filters_LowPass_Mid
# 69. Filters_LowPass_SamplingCut
# 70. Filters_LowPass_Smooth
# 71. Filters_LowPass_VerySmooth
# 72. ImpedanceTask_Left_Error_cx
# 73. ImpedanceTask_Left_Error_cy
# 74. ImpedanceTask_Left_Error_cz
# 75. ImpedanceTask_Left_Error_fx
# 76. ImpedanceTask_Left_Error_fy
# 77. ImpedanceTask_Left_Error_fz
# 78. ImpedanceTask_Left_MeasuredWrench_cx
# 79. ImpedanceTask_Left_MeasuredWrench_cy
# 80. ImpedanceTask_Left_MeasuredWrench_cz
# 81. ImpedanceTask_Left_MeasuredWrench_fx
# 82. ImpedanceTask_Left_MeasuredWrench_fy
# 83. ImpedanceTask_Left_MeasuredWrench_fz
# 84. ImpedanceTask_Left_TargetWrench_cx
# 85. ImpedanceTask_Left_TargetWrench_cy
# 86. ImpedanceTask_Left_TargetWrench_cz
# 87. ImpedanceTask_Left_TargetWrench_fx
# 88. ImpedanceTask_Left_TargetWrench_fy
# 89. ImpedanceTask_Left_TargetWrench_fz
# 90. ImpedanceTask_Right_Error_cx
# 91. ImpedanceTask_Right_Error_cy
# 92. ImpedanceTask_Right_Error_cz
# 93. ImpedanceTask_Right_Error_fx
# 94. ImpedanceTask_Right_Error_fy
# 95. ImpedanceTask_Right_Error_fz
# 96. ImpedanceTask_Right_MeasuredWrench_cx
# 97. ImpedanceTask_Right_MeasuredWrench_cy
# 98. ImpedanceTask_Right_MeasuredWrench_cz
# 99. ImpedanceTask_Right_MeasuredWrench_fx
# 100. ImpedanceTask_Right_MeasuredWrench_fy
# 101. ImpedanceTask_Right_MeasuredWrench_fz
# 102. ImpedanceTask_Right_TargetWrench_cx
# 103. ImpedanceTask_Right_TargetWrench_cy
# 104. ImpedanceTask_Right_TargetWrench_cz
# 105. ImpedanceTask_Right_TargetWrench_fx
# 106. ImpedanceTask_Right_TargetWrench_fy
# 107. ImpedanceTask_Right_TargetWrench_fz
# 108. InternalForce_DemandForce
# 109. InternalForce_Desired
# 110. InternalForce_Error
# 111. InternalForce_Measured
# 112. InternalForce_lambdaCommand
# 113. ObjectTrajectory_Desired_x
# 114. ObjectTrajectory_Desired_y
# 115. ObjectTrajectory_Desired_z
# 116. ObjectTrajectory_Real_x
# 117. ObjectTrajectory_Real_y
# 118. ObjectTrajectory_Real_z
# 119. alphaDOut_0
# 120. alphaDOut_1
# 121. alphaDOut_2
# 122. alphaDOut_3
# 123. alphaDOut_4
# 124. alphaDOut_5
# 125. alphaDOut_6
# 126. alphaIn_0
# 127. alphaIn_1
# 128. alphaIn_2
# 129. alphaIn_3
# 130. alphaIn_4
# 131. alphaIn_5
# 132. alphaIn_6
# 133. alphaOut_0
# 134. alphaOut_1
# 135. alphaOut_2
# 136. alphaOut_3
# 137. alphaOut_4
# 138. alphaOut_5
# 139. alphaOut_6
# 140. body6d_xarm7_2_link7_qw
# 141. body6d_xarm7_2_link7_qx
# 142. body6d_xarm7_2_link7_qy
# 143. body6d_xarm7_2_link7_qz
# 144. body6d_xarm7_2_link7_tx
# 145. body6d_xarm7_2_link7_ty
# 146. body6d_xarm7_2_link7_tz
# 147. body6d_xarm7_2_link7_orientation_w
# 148. body6d_xarm7_2_link7_orientation_x
# 149. body6d_xarm7_2_link7_orientation_y
# 150. body6d_xarm7_2_link7_orientation_z
# 151. body6d_xarm7_2_link7_orientation_damping
# 152. body6d_xarm7_2_link7_orientation_dimDamping_0
# 153. body6d_xarm7_2_link7_orientation_dimDamping_1
# 154. body6d_xarm7_2_link7_orientation_dimDamping_2
# 155. body6d_xarm7_2_link7_orientation_dimStiffness_0
# 156. body6d_xarm7_2_link7_orientation_dimStiffness_1
# 157. body6d_xarm7_2_link7_orientation_dimStiffness_2
# 158. body6d_xarm7_2_link7_orientation_dimWeight_0
# 159. body6d_xarm7_2_link7_orientation_dimWeight_1
# 160. body6d_xarm7_2_link7_orientation_dimWeight_2
# 161. body6d_xarm7_2_link7_orientation_refAccel_0
# 162. body6d_xarm7_2_link7_orientation_refAccel_1
# 163. body6d_xarm7_2_link7_orientation_refAccel_2
# 164. body6d_xarm7_2_link7_orientation_refVel_0
# 165. body6d_xarm7_2_link7_orientation_refVel_1
# 166. body6d_xarm7_2_link7_orientation_refVel_2
# 167. body6d_xarm7_2_link7_orientation_stiffness
# 168. body6d_xarm7_2_link7_orientation_target_w
# 169. body6d_xarm7_2_link7_orientation_target_x
# 170. body6d_xarm7_2_link7_orientation_target_y
# 171. body6d_xarm7_2_link7_orientation_target_z
# 172. body6d_xarm7_2_link7_orientation_weight
# 173. body6d_xarm7_2_link7_position_curPos_x
# 174. body6d_xarm7_2_link7_position_curPos_y
# 175. body6d_xarm7_2_link7_position_curPos_z
# 176. body6d_xarm7_2_link7_position_curVel_x
# 177. body6d_xarm7_2_link7_position_curVel_y
# 178. body6d_xarm7_2_link7_position_curVel_z
# 179. body6d_xarm7_2_link7_position_damping
# 180. body6d_xarm7_2_link7_position_dimDamping_0
# 181. body6d_xarm7_2_link7_position_dimDamping_1
# 182. body6d_xarm7_2_link7_position_dimDamping_2
# 183. body6d_xarm7_2_link7_position_dimStiffness_0
# 184. body6d_xarm7_2_link7_position_dimStiffness_1
# 185. body6d_xarm7_2_link7_position_dimStiffness_2
# 186. body6d_xarm7_2_link7_position_dimWeight_0
# 187. body6d_xarm7_2_link7_position_dimWeight_1
# 188. body6d_xarm7_2_link7_position_dimWeight_2
# 189. body6d_xarm7_2_link7_position_refAccel_0
# 190. body6d_xarm7_2_link7_position_refAccel_1
# 191. body6d_xarm7_2_link7_position_refAccel_2
# 192. body6d_xarm7_2_link7_position_refVel_0
# 193. body6d_xarm7_2_link7_position_refVel_1
# 194. body6d_xarm7_2_link7_position_refVel_2
# 195. body6d_xarm7_2_link7_position_stiffness
# 196. body6d_xarm7_2_link7_position_target_x
# 197. body6d_xarm7_2_link7_position_target_y
# 198. body6d_xarm7_2_link7_position_target_z
# 199. body6d_xarm7_2_link7_position_weight
# 200. body6d_xarm7_2_link7_target_qw
# 201. body6d_xarm7_2_link7_target_qx
# 202. body6d_xarm7_2_link7_target_qy
# 203. body6d_xarm7_2_link7_target_qz
# 204. body6d_xarm7_2_link7_target_tx
# 205. body6d_xarm7_2_link7_target_ty
# 206. body6d_xarm7_2_link7_target_tz
# 207. body6d_xarm7_link7_qw
# 208. body6d_xarm7_link7_qx
# 209. body6d_xarm7_link7_qy
# 210. body6d_xarm7_link7_qz
# 211. body6d_xarm7_link7_tx
# 212. body6d_xarm7_link7_ty
# 213. body6d_xarm7_link7_tz
# 214. body6d_xarm7_link7_orientation_w
# 215. body6d_xarm7_link7_orientation_x
# 216. body6d_xarm7_link7_orientation_y
# 217. body6d_xarm7_link7_orientation_z
# 218. body6d_xarm7_link7_orientation_damping
# 219. body6d_xarm7_link7_orientation_dimDamping_0
# 220. body6d_xarm7_link7_orientation_dimDamping_1
# 221. body6d_xarm7_link7_orientation_dimDamping_2
# 222. body6d_xarm7_link7_orientation_dimStiffness_0
# 223. body6d_xarm7_link7_orientation_dimStiffness_1
# 224. body6d_xarm7_link7_orientation_dimStiffness_2
# 225. body6d_xarm7_link7_orientation_dimWeight_0
# 226. body6d_xarm7_link7_orientation_dimWeight_1
# 227. body6d_xarm7_link7_orientation_dimWeight_2
# 228. body6d_xarm7_link7_orientation_refAccel_0
# 229. body6d_xarm7_link7_orientation_refAccel_1
# 230. body6d_xarm7_link7_orientation_refAccel_2
# 231. body6d_xarm7_link7_orientation_refVel_0
# 232. body6d_xarm7_link7_orientation_refVel_1
# 233. body6d_xarm7_link7_orientation_refVel_2
# 234. body6d_xarm7_link7_orientation_stiffness
# 235. body6d_xarm7_link7_orientation_target_w
# 236. body6d_xarm7_link7_orientation_target_x
# 237. body6d_xarm7_link7_orientation_target_y
# 238. body6d_xarm7_link7_orientation_target_z
# 239. body6d_xarm7_link7_orientation_weight
# 240. body6d_xarm7_link7_position_curPos_x
# 241. body6d_xarm7_link7_position_curPos_y
# 242. body6d_xarm7_link7_position_curPos_z
# 243. body6d_xarm7_link7_position_curVel_x
# 244. body6d_xarm7_link7_position_curVel_y
# 245. body6d_xarm7_link7_position_curVel_z
# 246. body6d_xarm7_link7_position_damping
# 247. body6d_xarm7_link7_position_dimDamping_0
# 248. body6d_xarm7_link7_position_dimDamping_1
# 249. body6d_xarm7_link7_position_dimDamping_2
# 250. body6d_xarm7_link7_position_dimStiffness_0
# 251. body6d_xarm7_link7_position_dimStiffness_1
# 252. body6d_xarm7_link7_position_dimStiffness_2
# 253. body6d_xarm7_link7_position_dimWeight_0
# 254. body6d_xarm7_link7_position_dimWeight_1
# 255. body6d_xarm7_link7_position_dimWeight_2
# 256. body6d_xarm7_link7_position_refAccel_0
# 257. body6d_xarm7_link7_position_refAccel_1
# 258. body6d_xarm7_link7_position_refAccel_2
# 259. body6d_xarm7_link7_position_refVel_0
# 260. body6d_xarm7_link7_position_refVel_1
# 261. body6d_xarm7_link7_position_refVel_2
# 262. body6d_xarm7_link7_position_stiffness
# 263. body6d_xarm7_link7_position_target_x
# 264. body6d_xarm7_link7_position_target_y
# 265. body6d_xarm7_link7_position_target_z
# 266. body6d_xarm7_link7_position_weight
# 267. body6d_xarm7_link7_target_qw
# 268. body6d_xarm7_link7_target_qx
# 269. body6d_xarm7_link7_target_qy
# 270. body6d_xarm7_link7_target_qz
# 271. body6d_xarm7_link7_target_tx
# 272. body6d_xarm7_link7_target_ty
# 273. body6d_xarm7_link7_target_tz
# 274. box1_FloatingBase_angularAcceleration_x
# 275. box1_FloatingBase_angularAcceleration_y
# 276. box1_FloatingBase_angularAcceleration_z
# 277. box1_FloatingBase_angularVelocity_x
# 278. box1_FloatingBase_angularVelocity_y
# 279. box1_FloatingBase_angularVelocity_z
# 280. box1_FloatingBase_linearAcceleration_x
# 281. box1_FloatingBase_linearAcceleration_y
# 282. box1_FloatingBase_linearAcceleration_z
# 283. box1_FloatingBase_linearVelocity_x
# 284. box1_FloatingBase_linearVelocity_y
# 285. box1_FloatingBase_linearVelocity_z
# 286. box1_FloatingBase_orientation_w
# 287. box1_FloatingBase_orientation_x
# 288. box1_FloatingBase_orientation_y
# 289. box1_FloatingBase_orientation_z
# 290. box1_FloatingBase_position_x
# 291. box1_FloatingBase_position_y
# 292. box1_FloatingBase_position_z
# 293. box1_ff_qw
# 294. box1_ff_qx
# 295. box1_ff_qy
# 296. box1_ff_qz
# 297. box1_ff_tx
# 298. box1_ff_ty
# 299. box1_ff_tz
# 300. box1_ff_real_qw
# 301. box1_ff_real_qx
# 302. box1_ff_real_qy
# 303. box1_ff_real_qz
# 304. box1_ff_real_tx
# 305. box1_ff_real_ty
# 306. box1_ff_real_tz
# 307. ground_Default_angularAcceleration_x
# 308. ground_Default_angularAcceleration_y
# 309. ground_Default_angularAcceleration_z
# 310. ground_Default_angularVelocity_x
# 311. ground_Default_angularVelocity_y
# 312. ground_Default_angularVelocity_z
# 313. ground_Default_linearAcceleration_x
# 314. ground_Default_linearAcceleration_y
# 315. ground_Default_linearAcceleration_z
# 316. ground_Default_linearVelocity_x
# 317. ground_Default_linearVelocity_y
# 318. ground_Default_linearVelocity_z
# 319. ground_Default_orientation_w
# 320. ground_Default_orientation_x
# 321. ground_Default_orientation_y
# 322. ground_Default_orientation_z
# 323. ground_Default_position_x
# 324. ground_Default_position_y
# 325. ground_Default_position_z
# 326. impedance_xarm7_2_link7_compliancePose_qw
# 327. impedance_xarm7_2_link7_compliancePose_qx
# 328. impedance_xarm7_2_link7_compliancePose_qy
# 329. impedance_xarm7_2_link7_compliancePose_qz
# 330. impedance_xarm7_2_link7_compliancePose_tx
# 331. impedance_xarm7_2_link7_compliancePose_ty
# 332. impedance_xarm7_2_link7_compliancePose_tz
# 333. impedance_xarm7_2_link7_cutoffPeriod
# 334. impedance_xarm7_2_link7_damping
# 335. impedance_xarm7_2_link7_deltaComplianceAccel_wx
# 336. impedance_xarm7_2_link7_deltaComplianceAccel_wy
# 337. impedance_xarm7_2_link7_deltaComplianceAccel_wz
# 338. impedance_xarm7_2_link7_deltaComplianceAccel_vx
# 339. impedance_xarm7_2_link7_deltaComplianceAccel_vy
# 340. impedance_xarm7_2_link7_deltaComplianceAccel_vz
# 341. impedance_xarm7_2_link7_deltaCompliancePose_qw
# 342. impedance_xarm7_2_link7_deltaCompliancePose_qx
# 343. impedance_xarm7_2_link7_deltaCompliancePose_qy
# 344. impedance_xarm7_2_link7_deltaCompliancePose_qz
# 345. impedance_xarm7_2_link7_deltaCompliancePose_tx
# 346. impedance_xarm7_2_link7_deltaCompliancePose_ty
# 347. impedance_xarm7_2_link7_deltaCompliancePose_tz
# 348. impedance_xarm7_2_link7_deltaComplianceVel_wx
# 349. impedance_xarm7_2_link7_deltaComplianceVel_wy
# 350. impedance_xarm7_2_link7_deltaComplianceVel_wz
# 351. impedance_xarm7_2_link7_deltaComplianceVel_vx
# 352. impedance_xarm7_2_link7_deltaComplianceVel_vy
# 353. impedance_xarm7_2_link7_deltaComplianceVel_vz
# 354. impedance_xarm7_2_link7_dimDamping_0
# 355. impedance_xarm7_2_link7_dimDamping_1
# 356. impedance_xarm7_2_link7_dimDamping_2
# 357. impedance_xarm7_2_link7_dimDamping_3
# 358. impedance_xarm7_2_link7_dimDamping_4
# 359. impedance_xarm7_2_link7_dimDamping_5
# 360. impedance_xarm7_2_link7_dimStiffness_0
# 361. impedance_xarm7_2_link7_dimStiffness_1
# 362. impedance_xarm7_2_link7_dimStiffness_2
# 363. impedance_xarm7_2_link7_dimStiffness_3
# 364. impedance_xarm7_2_link7_dimStiffness_4
# 365. impedance_xarm7_2_link7_dimStiffness_5
# 366. impedance_xarm7_2_link7_dimWeight_0
# 367. impedance_xarm7_2_link7_dimWeight_1
# 368. impedance_xarm7_2_link7_dimWeight_2
# 369. impedance_xarm7_2_link7_dimWeight_3
# 370. impedance_xarm7_2_link7_dimWeight_4
# 371. impedance_xarm7_2_link7_dimWeight_5
# 372. impedance_xarm7_2_link7_filteredMeasuredWrench_cx
# 373. impedance_xarm7_2_link7_filteredMeasuredWrench_cy
# 374. impedance_xarm7_2_link7_filteredMeasuredWrench_cz
# 375. impedance_xarm7_2_link7_filteredMeasuredWrench_fx
# 376. impedance_xarm7_2_link7_filteredMeasuredWrench_fy
# 377. impedance_xarm7_2_link7_filteredMeasuredWrench_fz
# 378. impedance_xarm7_2_link7_gains_D_wx
# 379. impedance_xarm7_2_link7_gains_D_wy
# 380. impedance_xarm7_2_link7_gains_D_wz
# 381. impedance_xarm7_2_link7_gains_D_vx
# 382. impedance_xarm7_2_link7_gains_D_vy
# 383. impedance_xarm7_2_link7_gains_D_vz
# 384. impedance_xarm7_2_link7_gains_K_wx
# 385. impedance_xarm7_2_link7_gains_K_wy
# 386. impedance_xarm7_2_link7_gains_K_wz
# 387. impedance_xarm7_2_link7_gains_K_vx
# 388. impedance_xarm7_2_link7_gains_K_vy
# 389. impedance_xarm7_2_link7_gains_K_vz
# 390. impedance_xarm7_2_link7_gains_M_wx
# 391. impedance_xarm7_2_link7_gains_M_wy
# 392. impedance_xarm7_2_link7_gains_M_wz
# 393. impedance_xarm7_2_link7_gains_M_vx
# 394. impedance_xarm7_2_link7_gains_M_vy
# 395. impedance_xarm7_2_link7_gains_M_vz
# 396. impedance_xarm7_2_link7_gains_wrench_wx
# 397. impedance_xarm7_2_link7_gains_wrench_wy
# 398. impedance_xarm7_2_link7_gains_wrench_wz
# 399. impedance_xarm7_2_link7_gains_wrench_vx
# 400. impedance_xarm7_2_link7_gains_wrench_vy
# 401. impedance_xarm7_2_link7_gains_wrench_vz
# 402. impedance_xarm7_2_link7_hold
# 403. impedance_xarm7_2_link7_measuredWrench_cx
# 404. impedance_xarm7_2_link7_measuredWrench_cy
# 405. impedance_xarm7_2_link7_measuredWrench_cz
# 406. impedance_xarm7_2_link7_measuredWrench_fx
# 407. impedance_xarm7_2_link7_measuredWrench_fy
# 408. impedance_xarm7_2_link7_measuredWrench_fz
# 409. impedance_xarm7_2_link7_pose_qw
# 410. impedance_xarm7_2_link7_pose_qx
# 411. impedance_xarm7_2_link7_pose_qy
# 412. impedance_xarm7_2_link7_pose_qz
# 413. impedance_xarm7_2_link7_pose_tx
# 414. impedance_xarm7_2_link7_pose_ty
# 415. impedance_xarm7_2_link7_pose_tz
# 416. impedance_xarm7_2_link7_refAccel_0
# 417. impedance_xarm7_2_link7_refAccel_1
# 418. impedance_xarm7_2_link7_refAccel_2
# 419. impedance_xarm7_2_link7_refAccel_3
# 420. impedance_xarm7_2_link7_refAccel_4
# 421. impedance_xarm7_2_link7_refAccel_5
# 422. impedance_xarm7_2_link7_refVel_0
# 423. impedance_xarm7_2_link7_refVel_1
# 424. impedance_xarm7_2_link7_refVel_2
# 425. impedance_xarm7_2_link7_refVel_3
# 426. impedance_xarm7_2_link7_refVel_4
# 427. impedance_xarm7_2_link7_refVel_5
# 428. impedance_xarm7_2_link7_stiffness
# 429. impedance_xarm7_2_link7_targetAccel_wx
# 430. impedance_xarm7_2_link7_targetAccel_wy
# 431. impedance_xarm7_2_link7_targetAccel_wz
# 432. impedance_xarm7_2_link7_targetAccel_vx
# 433. impedance_xarm7_2_link7_targetAccel_vy
# 434. impedance_xarm7_2_link7_targetAccel_vz
# 435. impedance_xarm7_2_link7_targetPose_qw
# 436. impedance_xarm7_2_link7_targetPose_qx
# 437. impedance_xarm7_2_link7_targetPose_qy
# 438. impedance_xarm7_2_link7_targetPose_qz
# 439. impedance_xarm7_2_link7_targetPose_tx
# 440. impedance_xarm7_2_link7_targetPose_ty
# 441. impedance_xarm7_2_link7_targetPose_tz
# 442. impedance_xarm7_2_link7_targetVel_wx
# 443. impedance_xarm7_2_link7_targetVel_wy
# 444. impedance_xarm7_2_link7_targetVel_wz
# 445. impedance_xarm7_2_link7_targetVel_vx
# 446. impedance_xarm7_2_link7_targetVel_vy
# 447. impedance_xarm7_2_link7_targetVel_vz
# 448. impedance_xarm7_2_link7_targetWrench_cx
# 449. impedance_xarm7_2_link7_targetWrench_cy
# 450. impedance_xarm7_2_link7_targetWrench_cz
# 451. impedance_xarm7_2_link7_targetWrench_fx
# 452. impedance_xarm7_2_link7_targetWrench_fy
# 453. impedance_xarm7_2_link7_targetWrench_fz
# 454. impedance_xarm7_2_link7_target_pose_qw
# 455. impedance_xarm7_2_link7_target_pose_qx
# 456. impedance_xarm7_2_link7_target_pose_qy
# 457. impedance_xarm7_2_link7_target_pose_qz
# 458. impedance_xarm7_2_link7_target_pose_tx
# 459. impedance_xarm7_2_link7_target_pose_ty
# 460. impedance_xarm7_2_link7_target_pose_tz
# 461. impedance_xarm7_2_link7_weight
# 462. impedance_xarm7_link7_compliancePose_qw
# 463. impedance_xarm7_link7_compliancePose_qx
# 464. impedance_xarm7_link7_compliancePose_qy
# 465. impedance_xarm7_link7_compliancePose_qz
# 466. impedance_xarm7_link7_compliancePose_tx
# 467. impedance_xarm7_link7_compliancePose_ty
# 468. impedance_xarm7_link7_compliancePose_tz
# 469. impedance_xarm7_link7_cutoffPeriod
# 470. impedance_xarm7_link7_damping
# 471. impedance_xarm7_link7_deltaComplianceAccel_wx
# 472. impedance_xarm7_link7_deltaComplianceAccel_wy
# 473. impedance_xarm7_link7_deltaComplianceAccel_wz
# 474. impedance_xarm7_link7_deltaComplianceAccel_vx
# 475. impedance_xarm7_link7_deltaComplianceAccel_vy
# 476. impedance_xarm7_link7_deltaComplianceAccel_vz
# 477. impedance_xarm7_link7_deltaCompliancePose_qw
# 478. impedance_xarm7_link7_deltaCompliancePose_qx
# 479. impedance_xarm7_link7_deltaCompliancePose_qy
# 480. impedance_xarm7_link7_deltaCompliancePose_qz
# 481. impedance_xarm7_link7_deltaCompliancePose_tx
# 482. impedance_xarm7_link7_deltaCompliancePose_ty
# 483. impedance_xarm7_link7_deltaCompliancePose_tz
# 484. impedance_xarm7_link7_deltaComplianceVel_wx
# 485. impedance_xarm7_link7_deltaComplianceVel_wy
# 486. impedance_xarm7_link7_deltaComplianceVel_wz
# 487. impedance_xarm7_link7_deltaComplianceVel_vx
# 488. impedance_xarm7_link7_deltaComplianceVel_vy
# 489. impedance_xarm7_link7_deltaComplianceVel_vz
# 490. impedance_xarm7_link7_dimDamping_0
# 491. impedance_xarm7_link7_dimDamping_1
# 492. impedance_xarm7_link7_dimDamping_2
# 493. impedance_xarm7_link7_dimDamping_3
# 494. impedance_xarm7_link7_dimDamping_4
# 495. impedance_xarm7_link7_dimDamping_5
# 496. impedance_xarm7_link7_dimStiffness_0
# 497. impedance_xarm7_link7_dimStiffness_1
# 498. impedance_xarm7_link7_dimStiffness_2
# 499. impedance_xarm7_link7_dimStiffness_3
# 500. impedance_xarm7_link7_dimStiffness_4
# 501. impedance_xarm7_link7_dimStiffness_5
# 502. impedance_xarm7_link7_dimWeight_0
# 503. impedance_xarm7_link7_dimWeight_1
# 504. impedance_xarm7_link7_dimWeight_2
# 505. impedance_xarm7_link7_dimWeight_3
# 506. impedance_xarm7_link7_dimWeight_4
# 507. impedance_xarm7_link7_dimWeight_5
# 508. impedance_xarm7_link7_filteredMeasuredWrench_cx
# 509. impedance_xarm7_link7_filteredMeasuredWrench_cy
# 510. impedance_xarm7_link7_filteredMeasuredWrench_cz
# 511. impedance_xarm7_link7_filteredMeasuredWrench_fx
# 512. impedance_xarm7_link7_filteredMeasuredWrench_fy
# 513. impedance_xarm7_link7_filteredMeasuredWrench_fz
# 514. impedance_xarm7_link7_gains_D_wx
# 515. impedance_xarm7_link7_gains_D_wy
# 516. impedance_xarm7_link7_gains_D_wz
# 517. impedance_xarm7_link7_gains_D_vx
# 518. impedance_xarm7_link7_gains_D_vy
# 519. impedance_xarm7_link7_gains_D_vz
# 520. impedance_xarm7_link7_gains_K_wx
# 521. impedance_xarm7_link7_gains_K_wy
# 522. impedance_xarm7_link7_gains_K_wz
# 523. impedance_xarm7_link7_gains_K_vx
# 524. impedance_xarm7_link7_gains_K_vy
# 525. impedance_xarm7_link7_gains_K_vz
# 526. impedance_xarm7_link7_gains_M_wx
# 527. impedance_xarm7_link7_gains_M_wy
# 528. impedance_xarm7_link7_gains_M_wz
# 529. impedance_xarm7_link7_gains_M_vx
# 530. impedance_xarm7_link7_gains_M_vy
# 531. impedance_xarm7_link7_gains_M_vz
# 532. impedance_xarm7_link7_gains_wrench_wx
# 533. impedance_xarm7_link7_gains_wrench_wy
# 534. impedance_xarm7_link7_gains_wrench_wz
# 535. impedance_xarm7_link7_gains_wrench_vx
# 536. impedance_xarm7_link7_gains_wrench_vy
# 537. impedance_xarm7_link7_gains_wrench_vz
# 538. impedance_xarm7_link7_hold
# 539. impedance_xarm7_link7_measuredWrench_cx
# 540. impedance_xarm7_link7_measuredWrench_cy
# 541. impedance_xarm7_link7_measuredWrench_cz
# 542. impedance_xarm7_link7_measuredWrench_fx
# 543. impedance_xarm7_link7_measuredWrench_fy
# 544. impedance_xarm7_link7_measuredWrench_fz
# 545. impedance_xarm7_link7_pose_qw
# 546. impedance_xarm7_link7_pose_qx
# 547. impedance_xarm7_link7_pose_qy
# 548. impedance_xarm7_link7_pose_qz
# 549. impedance_xarm7_link7_pose_tx
# 550. impedance_xarm7_link7_pose_ty
# 551. impedance_xarm7_link7_pose_tz
# 552. impedance_xarm7_link7_refAccel_0
# 553. impedance_xarm7_link7_refAccel_1
# 554. impedance_xarm7_link7_refAccel_2
# 555. impedance_xarm7_link7_refAccel_3
# 556. impedance_xarm7_link7_refAccel_4
# 557. impedance_xarm7_link7_refAccel_5
# 558. impedance_xarm7_link7_refVel_0
# 559. impedance_xarm7_link7_refVel_1
# 560. impedance_xarm7_link7_refVel_2
# 561. impedance_xarm7_link7_refVel_3
# 562. impedance_xarm7_link7_refVel_4
# 563. impedance_xarm7_link7_refVel_5
# 564. impedance_xarm7_link7_stiffness
# 565. impedance_xarm7_link7_targetAccel_wx
# 566. impedance_xarm7_link7_targetAccel_wy
# 567. impedance_xarm7_link7_targetAccel_wz
# 568. impedance_xarm7_link7_targetAccel_vx
# 569. impedance_xarm7_link7_targetAccel_vy
# 570. impedance_xarm7_link7_targetAccel_vz
# 571. impedance_xarm7_link7_targetPose_qw
# 572. impedance_xarm7_link7_targetPose_qx
# 573. impedance_xarm7_link7_targetPose_qy
# 574. impedance_xarm7_link7_targetPose_qz
# 575. impedance_xarm7_link7_targetPose_tx
# 576. impedance_xarm7_link7_targetPose_ty
# 577. impedance_xarm7_link7_targetPose_tz
# 578. impedance_xarm7_link7_targetVel_wx
# 579. impedance_xarm7_link7_targetVel_wy
# 580. impedance_xarm7_link7_targetVel_wz
# 581. impedance_xarm7_link7_targetVel_vx
# 582. impedance_xarm7_link7_targetVel_vy
# 583. impedance_xarm7_link7_targetVel_vz
# 584. impedance_xarm7_link7_targetWrench_cx
# 585. impedance_xarm7_link7_targetWrench_cy
# 586. impedance_xarm7_link7_targetWrench_cz
# 587. impedance_xarm7_link7_targetWrench_fx
# 588. impedance_xarm7_link7_targetWrench_fy
# 589. impedance_xarm7_link7_targetWrench_fz
# 590. impedance_xarm7_link7_target_pose_qw
# 591. impedance_xarm7_link7_target_pose_qx
# 592. impedance_xarm7_link7_target_pose_qy
# 593. impedance_xarm7_link7_target_pose_qz
# 594. impedance_xarm7_link7_target_pose_tx
# 595. impedance_xarm7_link7_target_pose_ty
# 596. impedance_xarm7_link7_target_pose_tz
# 597. impedance_xarm7_link7_weight
# 598. motionFinished_
# 599. motionStarted_
# 600. perf_ControllerRun
# 601. perf_FrameworkCost
# 602. perf_GlobalRun
# 603. perf_Gui
# 604. perf_Log
# 605. perf_ObserversRun
# 606. perf_Plugins_ROS_after
# 607. perf_SolverBuildAndSolve
# 608. perf_SolverSolve
# 609. perf_UpdateContacts
# 610. posture_xarm7_2_eval_0
# 611. posture_xarm7_2_eval_1
# 612. posture_xarm7_2_eval_2
# 613. posture_xarm7_2_eval_3
# 614. posture_xarm7_2_eval_4
# 615. posture_xarm7_2_eval_5
# 616. posture_xarm7_2_eval_6
# 617. posture_xarm7_2_refAccel_0
# 618. posture_xarm7_2_refAccel_1
# 619. posture_xarm7_2_refAccel_2
# 620. posture_xarm7_2_refAccel_3
# 621. posture_xarm7_2_refAccel_4
# 622. posture_xarm7_2_refAccel_5
# 623. posture_xarm7_2_refAccel_6
# 624. posture_xarm7_2_refVel_0
# 625. posture_xarm7_2_refVel_1
# 626. posture_xarm7_2_refVel_2
# 627. posture_xarm7_2_refVel_3
# 628. posture_xarm7_2_refVel_4
# 629. posture_xarm7_2_refVel_5
# 630. posture_xarm7_2_refVel_6
# 631. posture_xarm7_2_speed_0
# 632. posture_xarm7_2_speed_1
# 633. posture_xarm7_2_speed_2
# 634. posture_xarm7_2_speed_3
# 635. posture_xarm7_2_speed_4
# 636. posture_xarm7_2_speed_5
# 637. posture_xarm7_2_speed_6
# 638. posture_xarm7_eval_0
# 639. posture_xarm7_eval_1
# 640. posture_xarm7_eval_2
# 641. posture_xarm7_eval_3
# 642. posture_xarm7_eval_4
# 643. posture_xarm7_eval_5
# 644. posture_xarm7_eval_6
# 645. posture_xarm7_refAccel_0
# 646. posture_xarm7_refAccel_1
# 647. posture_xarm7_refAccel_2
# 648. posture_xarm7_refAccel_3
# 649. posture_xarm7_refAccel_4
# 650. posture_xarm7_refAccel_5
# 651. posture_xarm7_refAccel_6
# 652. posture_xarm7_refVel_0
# 653. posture_xarm7_refVel_1
# 654. posture_xarm7_refVel_2
# 655. posture_xarm7_refVel_3
# 656. posture_xarm7_refVel_4
# 657. posture_xarm7_refVel_5
# 658. posture_xarm7_refVel_6
# 659. posture_xarm7_speed_0
# 660. posture_xarm7_speed_1
# 661. posture_xarm7_speed_2
# 662. posture_xarm7_speed_3
# 663. posture_xarm7_speed_4
# 664. posture_xarm7_speed_5
# 665. posture_xarm7_speed_6
# 666. qIn_0
# 667. qIn_1
# 668. qIn_2
# 669. qIn_3
# 670. qIn_4
# 671. qIn_5
# 672. qIn_6
# 673. qOut_0
# 674. qOut_1
# 675. qOut_2
# 676. qOut_3
# 677. qOut_4
# 678. qOut_5
# 679. qOut_6
# 680. t
# 681. tauIn_0
# 682. tauIn_1
# 683. tauIn_2
# 684. tauIn_3
# 685. tauIn_4
# 686. tauIn_5
# 687. tauIn_6
# 688. tauOut_0
# 689. tauOut_1
# 690. tauOut_2
# 691. tauOut_3
# 692. tauOut_4
# 693. tauOut_5
# 694. tauOut_6
# 695. timeWall
# 696. xarm7_2_Default_angularAcceleration_x
# 697. xarm7_2_Default_angularAcceleration_y
# 698. xarm7_2_Default_angularAcceleration_z
# 699. xarm7_2_Default_angularVelocity_x
# 700. xarm7_2_Default_angularVelocity_y
# 701. xarm7_2_Default_angularVelocity_z
# 702. xarm7_2_Default_linearAcceleration_x
# 703. xarm7_2_Default_linearAcceleration_y
# 704. xarm7_2_Default_linearAcceleration_z
# 705. xarm7_2_Default_linearVelocity_x
# 706. xarm7_2_Default_linearVelocity_y
# 707. xarm7_2_Default_linearVelocity_z
# 708. xarm7_2_Default_orientation_w
# 709. xarm7_2_Default_orientation_x
# 710. xarm7_2_Default_orientation_y
# 711. xarm7_2_Default_orientation_z
# 712. xarm7_2_Default_position_x
# 713. xarm7_2_Default_position_y
# 714. xarm7_2_Default_position_z
# 715. xarm7_2_EEForceSensor_cx
# 716. xarm7_2_EEForceSensor_cy
# 717. xarm7_2_EEForceSensor_cz
# 718. xarm7_2_EEForceSensor_fx
# 719. xarm7_2_EEForceSensor_fy
# 720. xarm7_2_EEForceSensor_fz
# 721. xarm7_2_alphaDOut_0
# 722. xarm7_2_alphaDOut_1
# 723. xarm7_2_alphaDOut_2
# 724. xarm7_2_alphaDOut_3
# 725. xarm7_2_alphaDOut_4
# 726. xarm7_2_alphaDOut_5
# 727. xarm7_2_alphaDOut_6
# 728. xarm7_2_alphaIn_0
# 729. xarm7_2_alphaIn_1
# 730. xarm7_2_alphaIn_2
# 731. xarm7_2_alphaIn_3
# 732. xarm7_2_alphaIn_4
# 733. xarm7_2_alphaIn_5
# 734. xarm7_2_alphaIn_6
# 735. xarm7_2_alphaOut_0
# 736. xarm7_2_alphaOut_1
# 737. xarm7_2_alphaOut_2
# 738. xarm7_2_alphaOut_3
# 739. xarm7_2_alphaOut_4
# 740. xarm7_2_alphaOut_5
# 741. xarm7_2_alphaOut_6
# 742. xarm7_2_qIn_0
# 743. xarm7_2_qIn_1
# 744. xarm7_2_qIn_2
# 745. xarm7_2_qIn_3
# 746. xarm7_2_qIn_4
# 747. xarm7_2_qIn_5
# 748. xarm7_2_qIn_6
# 749. xarm7_2_qOut_0
# 750. xarm7_2_qOut_1
# 751. xarm7_2_qOut_2
# 752. xarm7_2_qOut_3
# 753. xarm7_2_qOut_4
# 754. xarm7_2_qOut_5
# 755. xarm7_2_qOut_6
# 756. xarm7_2_tauIn_0
# 757. xarm7_2_tauIn_1
# 758. xarm7_2_tauIn_2
# 759. xarm7_2_tauIn_3
# 760. xarm7_2_tauIn_4
# 761. xarm7_2_tauIn_5
# 762. xarm7_2_tauIn_6
# 763. xarm7_2_tauOut_0
# 764. xarm7_2_tauOut_1
# 765. xarm7_2_tauOut_2
# 766. xarm7_2_tauOut_3
# 767. xarm7_2_tauOut_4
# 768. xarm7_2_tauOut_5
# 769. xarm7_2_tauOut_6

# %% [markdown]
# # Fields

# %%
time = df["t"].to_numpy()

# --- INTERNAL FORCES ---
internalDesiredForce =  df[["InternalForce_Desired"]].to_numpy()
internalMeasuredForce = df[["InternalForce_Measured"]].to_numpy()

# --- CURRENT STATE ---
currentstate = df[["CurrentState"]].to_numpy()

# --- OBJECT TRAFECTORY ---
ObjectPlannedTrajectory = df[["ObjectTrajectory_Desired_x", "ObjectTrajectory_Desired_y", "ObjectTrajectory_Desired_z"]].to_numpy()
ObjectRealTrajectory = df[["ObjectTrajectory_Real_x", "ObjectTrajectory_Real_y", "ObjectTrajectory_Real_z"]].to_numpy()

# --- ANGULAR VELOCITY ---
RigtArmIn_dq = df[["xarm7_2_qIn_0","xarm7_2_qIn_1","xarm7_2_qIn_2","xarm7_2_qIn_3","xarm7_2_qIn_4","xarm7_2_qIn_5","xarm7_2_qIn_6"]].to_numpy()
RigtArmOut_dq = df[["xarm7_2_qOut_0","xarm7_2_qOut_1","xarm7_2_qOut_2","xarm7_2_qOut_3","xarm7_2_qOut_4","xarm7_2_qOut_5","xarm7_2_qOut_6"]].to_numpy()

LeftArmIn_dq = df[["qIn_0","qIn_1","qIn_2","qIn_3","qIn_4","qIn_5","qIn_6"]].to_numpy()
LeftArmOut_dq = df[["qOut_0","qOut_1","qOut_2","qOut_3","qOut_4","qOut_5","qOut_6"]].to_numpy()

# --- TORQUES ---
RigtArmIn_tau = df[["xarm7_2_tauIn_0","xarm7_2_tauIn_1","xarm7_2_tauIn_2","xarm7_2_tauIn_3","xarm7_2_tauIn_4","xarm7_2_tauIn_5","xarm7_2_tauIn_6"]].to_numpy()
RigtArmOut_tau = df[["xarm7_2_tauOut_0","xarm7_2_tauOut_1","xarm7_2_tauOut_2","xarm7_2_tauOut_3","xarm7_2_tauOut_4","xarm7_2_tauOut_5","xarm7_2_tauOut_6"]].to_numpy()

LeftArmIn_tau = df[["tauIn_0","tauIn_1","tauIn_2","tauIn_3","tauIn_4","tauIn_5","tauIn_6"]].to_numpy()
LeftArmOut_tau = df[["tauOut_0","tauOut_1","tauOut_2","tauOut_3","tauOut_4","tauOut_5","tauOut_6"]].to_numpy()

trajectoryFlags = df[["motionFinished_", "motionStarted_"]].to_numpy()

# %%
exp2_time = np["t"].to_numpy()

# --- INTERNAL FORCES ---
exp2_internalDesiredForce =  np[["InternalForce_Desired"]].to_numpy()
exp2_internalMeasuredForce = np[["InternalForce_Measured"]].to_numpy()

# --- CURRENT STATE ---
exp2_currentstate = np[["CurrentState"]].to_numpy()

# --- OBJECT TRAFECTORY ---
exp2_ObjectPlannedTrajectory = np[["ObjectTrajectory_Desired_x", "ObjectTrajectory_Desired_y", "ObjectTrajectory_Desired_z"]].to_numpy()
exp2_ObjectRealTrajectory = np[["ObjectTrajectory_Real_x", "ObjectTrajectory_Real_y", "ObjectTrajectory_Real_z"]].to_numpy()

# --- ANGULAR VELOCITY ---
exp2_RigtArmIn_dq = np[["xarm7_2_qIn_0","xarm7_2_qIn_1","xarm7_2_qIn_2","xarm7_2_qIn_3","xarm7_2_qIn_4","xarm7_2_qIn_5","xarm7_2_qIn_6"]].to_numpy()
exp2_RigtArmOut_dq = np[["xarm7_2_qOut_0","xarm7_2_qOut_1","xarm7_2_qOut_2","xarm7_2_qOut_3","xarm7_2_qOut_4","xarm7_2_qOut_5","xarm7_2_qOut_6"]].to_numpy()

exp2_LeftArmIn_dq = np[["qIn_0","qIn_1","qIn_2","qIn_3","qIn_4","qIn_5","qIn_6"]].to_numpy()
exp2_LeftArmOut_dq = np[["qOut_0","qOut_1","qOut_2","qOut_3","qOut_4","qOut_5","qOut_6"]].to_numpy()

# --- TORQUES ---
exp2_RigtArmIn_tau = np[["xarm7_2_tauIn_0","xarm7_2_tauIn_1","xarm7_2_tauIn_2","xarm7_2_tauIn_3","xarm7_2_tauIn_4","xarm7_2_tauIn_5","xarm7_2_tauIn_6"]].to_numpy()
exp2_RigtArmOut_tau = np[["xarm7_2_tauOut_0","xarm7_2_tauOut_1","xarm7_2_tauOut_2","xarm7_2_tauOut_3","xarm7_2_tauOut_4","xarm7_2_tauOut_5","xarm7_2_tauOut_6"]].to_numpy()

exp2_LeftArmIn_tau = np[["tauIn_0","tauIn_1","tauIn_2","tauIn_3","tauIn_4","tauIn_5","tauIn_6"]].to_numpy()
exp2_LeftArmOut_tau = np[["tauOut_0","tauOut_1","tauOut_2","tauOut_3","tauOut_4","tauOut_5","tauOut_6"]].to_numpy()

exp2_trajectoryFlags = np[["motionFinished_", "motionStarted_"]].to_numpy()

# %%
import numpy as np

# Find first 0 -> 1 transition for each flag
start_transition = np.where(np.diff(trajectoryFlags[:, 0].astype(int)) == 1)[0]
finish_transition = np.where(np.diff(trajectoryFlags[:, 1].astype(int)) == 1)[0]

start_time = None
finish_time = None

if len(start_transition) > 0:
    start_idx = start_transition[0] + 1
    start_time = time[start_idx]
    print(f"Motion starts at index {start_idx}, time = {start_time:.3f} s")

if len(finish_transition) > 0:
    finish_idx = finish_transition[0] + 1
    finish_time = time[finish_idx]
    print(f"Motion finishes at index {finish_idx}, time = {finish_time:.3f} s")
# Out:
# Motion finishes at index 39390, time = 39.390 s

# %% [markdown]
# # Plot Template

# %%
from contextlib import contextmanager
import logging
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib import font_manager

# Configurazione log essenziale per avvisare in caso di fallback del font
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("PlotTemplate")


class PlotTemplate:
    """Wrapper flessibile per Matplotlib: gestione automatica dei font,
    palette di colori armonica, legenda rapida e sintassi pulita."""

    # Palette di default armonizzata (usata nel color cycle automatico di matplotlib)
    PALETTE = [
        "#005587",  # Blu (Accent principale)
        "#E05A47",  # Rosso/Arancio
        "#2A9D8F",  # Verde ottanio
        "#E9C46A",  # Giallo dorato
        "#6A4C93",  # Viola
    ]

    BASE = "#333333"        # Testi, assi e griglie
    GRID_COLOR = "#E0E0E0"
    ZERO_LINE_COLOR = "#CCCCCC"

    def __init__(self, font_name="DejaVu Sans", font_path=None, base_font_size=16, palette=None):
        self.base_font_size = base_font_size
        self.palette = palette or self.PALETTE
        
        # Imposta il font iniziale
        self.font_name = self._resolve_font(font_name, font_path)
        self._apply_global_rc()

    def _resolve_font(self, font_name, font_path=None):
        """Verifica la disponibilità del font. Se manca, fa fallback su DejaVu Sans senza arrestarsi."""
        if font_path and Path(font_path).exists():
            try:
                font_manager.fontManager.addfont(str(font_path))
                return font_manager.FontProperties(fname=str(font_path)).get_name()
            except Exception as e:
                logger.warning(f"Impossibile caricare il font da file '{font_path}': {e}. Fallback al default.")
        
        # Controlla se il font_name è installato nel sistema
        system_fonts = {f.name.lower() for f in font_manager.fontManager.ttflist}
        if font_name.lower() in system_fonts or font_name in ["DejaVu Sans", "sans-serif", "serif", "monospace"]:
            return font_name
        
        logger.warning(f"Font '{font_name}' non trovato nel sistema. Fallback a 'DejaVu Sans'.")
        return "DejaVu Sans"

    def set_font(self, font_name, font_path=None):
        """Permette di cambiare font al volo: pt.set_font('Roboto')"""
        self.font_name = self._resolve_font(font_name, font_path)
        plt.rcParams["font.family"] = self.font_name

    def set_font_size(self, base_size):
            """Permette di cambiare la dimensione base al volo per tutti gli elementi."""
            self.base_font_size = base_size
            plt.rcParams.update({
                "font.size": base_size,
                "axes.titlesize": round(base_size * 1.),   # Titolo del singolo grafico (+15%)
                "figure.titlesize": round(base_size * 1),  # Titolo generale con fig.suptitle (+30%)
                "axes.labelsize": round(base_size * 0.95),   # Etichette degli assi (xlabel, ylabel)
                "xtick.labelsize": round(base_size * 0.9),  # Numeri/valori sull'asse X
                "ytick.labelsize": round(base_size * 0.9),  # Numeri/valori sull'asse Y
                "legend.fontsize": round(base_size * 0.9),  # Testo della legenda
            })

    def _apply_global_rc(self):
        """Applica gli stili di base e la ciclicità dei colori a Matplotlib."""
        rc = {
            "font.family": self.font_name,
            "axes.prop_cycle": plt.cycler(color=self.palette),  # Colori automatici!
            "text.color": self.BASE,
            "axes.labelcolor": self.BASE,
            "xtick.color": self.BASE,
            "ytick.color": self.BASE,
            "figure.constrained_layout.use": True,
        }
        plt.rcParams.update(rc)
        self.set_font_size(self.base_font_size)

    # ---------- Core API ----------

    def create(
        self,
        xlabel="",
        ylabel="",
        title="",
        figsize=(8, 5),
        nrows=1,
        ncols=1,
        zero_lines=False,
        font_name=None,
        font_size=None,
        **subplot_kwargs
    ):
        """Crea la figura e gli assi configurati."""
        # Override temporanei di font o dimensione per questo specifico grafico
        if font_name:
            plt.rcParams["font.family"] = self._resolve_font(font_name)
        if font_size:
            self.set_font_size(font_size)

        fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, **subplot_kwargs)
        axes = ax.flatten().tolist() if nrows * ncols > 1 else [ax]

        for a in axes:
            self._format_axes(a, zero_lines=zero_lines)

        if nrows * ncols == 1:
            ax.set_xlabel(xlabel)
            ax.set_ylabel(ylabel)
            ax.set_title(title)
        elif title:
            fig.suptitle(title)

        return fig, ax

    def finish(self, fig, ax=None, save=None, dpi=300, show=True, legend=False, legend_loc="best"):
        """Finalizes plot, adds legends to all subplots, and saves/shows."""
        if legend and ax is not None:
            # Convert single ax or numpy array of axes into a flat list
            axes = [ax] if not hasattr(ax, "__len__") else (
                ax.flatten().tolist() if hasattr(ax, "flatten") else list(ax)
            )
            for a in axes:
                handles, labels = a.get_legend_handles_labels()
                if handles:
                    a.legend(loc=legend_loc, frameon=True, facecolor="white", edgecolor="none")

        if not plt.rcParams["figure.constrained_layout.use"]:
            fig.tight_layout()

        if save:
            fig.savefig(save, dpi=dpi, bbox_inches="tight")
        
        if show:
            plt.show()
        else:
            plt.close(fig)

    @contextmanager
    def figure(
        self,
        xlabel="",
        ylabel="",
        title="",
        figsize=(8, 5),
        save=None,
        dpi=300,
        show=True,
        legend=False,
        legend_loc="best",
        font_name=None,
        font_size=None,
        **subplot_kwargs
    ):
        """Context manager per creare e chiudere automaticamente la figura."""
        fig, ax = self.create(
            xlabel=xlabel,
            ylabel=ylabel,
            title=title,
            figsize=figsize,
            font_name=font_name,
            font_size=font_size,
            **subplot_kwargs
        )
        try:
            yield fig, ax
        finally:
            self.finish(fig, ax=ax, save=save, dpi=dpi, show=show, legend=legend, legend_loc=legend_loc)

    # ---------- Internal Helper ----------

    def _format_axes(self, ax, zero_lines=False):
        ax.grid(True, linestyle=":", color=self.GRID_COLOR, lw=0.8, zorder=1)
        if zero_lines:
            ax.axhline(0, color=self.ZERO_LINE_COLOR, lw=0.8, zorder=1)
            ax.axvline(0, color=self.ZERO_LINE_COLOR, lw=0.8, zorder=1)
        
        for spine in ("top", "right"):
            ax.spines[spine].set_visible(False)
        for spine in ("left", "bottom"):
            ax.spines[spine].set_color(self.BASE)
            ax.spines[spine].set_linewidth(0.8)
# Out:
# /home/luca/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
#  ---

# %% [markdown]
# # Plots

# %% [markdown]
# ## Global Parameters

# %%
xlim_l = 32.5
xlim_u = 130.5

ylim_l = -2
ylim_u = 45

lw = 1.5

# %%
internalForce = PlotTemplate()

x = time
y1 = internalDesiredForce
y2 = internalMeasuredForce


x1 = exp2_time
y3 = exp2_internalDesiredForce
y4 = exp2_internalMeasuredForce



with internalForce.figure(
    xlabel="Time (s)", 
    ylabel="Newtons (N)", 
    title="Internal Forces", 
    save = "InternalForce.png",
    legend=True,
    dpi=600,
    nrows=2,
    #figsize=(8, 6),
    font_name = "Roboto",
    font_size=16,

    legend_loc="lower right"
    ) as (fig, ax):

        # Colora lo sfondo
        ax[0].axvspan(xlim_l, 42, facecolor="#ffb4a2", alpha=0.2)
        ax[0].axvspan(42, 122, facecolor="#e5989b", alpha=0.2)
        ax[0].axvspan(122, xlim_u, facecolor="#b5838d", alpha=0.2)

        y_text = ylim_l + 0.95 * (ylim_u - ylim_l)

        ax[0].text((xlim_l + 50) / 2, y_text, "Pre-Tracking", ha="center", va="center", fontsize=16,fontname="Roboto")
        ax[0].text(80, y_text, "Trajectory Tracking", ha="center", va="center", fontsize=16,fontname="Roboto")
        ax[0].text((110 + xlim_u) / 2, y_text, "Post-Tracking", ha="center", va="center", fontsize=16,fontname="Roboto")

        # Curve
        ax[0].plot(x, y1, label="Desired", linestyle="--", lw=lw, alpha=0.9)
        ax[0].plot(x, y2, label="Measured", linestyle="-", lw=lw)

        # Linee verticali
        ax[0].axvline(42, color="black", linestyle="--", linewidth=1,alpha=0.3)
        ax[0].axvline(122, color="black", linestyle="--", linewidth=1,alpha=0.3)

        ax[0].set_xlim(xlim_l, xlim_u)
        ax[0].set_ylim(ylim_l, ylim_u)
        ax[0].grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")

        ax[0].tick_params(labelbottom=False)




                # Colora lo sfondo
        ax[1].sharex(ax[0])
        ax[1].axvspan(xlim_l, 42, facecolor="#ffb4a2", alpha=0.2)
        ax[1].axvspan(42, 122, facecolor="#e5989b", alpha=0.2)
        ax[1].axvspan(122, xlim_u, facecolor="#b5838d", alpha=0.2)



        # Curve
        ax[1].plot(x1, y3, label="Desired", linestyle="--", lw=lw, alpha=0.9)
        ax[1].plot(x1, y4, label="Measured", linestyle="-", lw=lw)

        # Linee verticali
        ax[1].axvline(42, color="black", linestyle="--", linewidth=1,alpha=0.3)
        ax[1].axvline(122, color="black", linestyle="--", linewidth=1,alpha=0.3)

        ax[1].set_xlim(xlim_l, xlim_u)
        ax[1].set_ylim(ylim_l, ylim_u)
        ax[1].grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")

# %%
trajectory = PlotTemplate()

x = time
y1Vector = ObjectPlannedTrajectory  # Shape: (3, N)
y2Vector = ObjectRealTrajectory     # Shape: (3, N)


with trajectory.figure(
    xlabel="Time (s)", 
    ylabel="Meters (m)", 
    figsize=(8, 10),            # Increased height so 3 subplots aren't squished
    legend=True,
    #save = "ObjectTrajecory.png",
    show = False,
    legend_loc="lower right",
    nrows=3,
    font_name="Roboto",
    font_size=16                # Slightly smaller font size works better with 3 subplots
) as (fig, ax):

    # Subplot 1 (Top / X Axis)
    ax[0].plot(x, y1Vector[:,0], label="Desired", lw=lw)
    ax[0].plot(x, y2Vector[:,0], label="Real", lw=lw)
    ax[0].set_xlim(xlim_l, xlim_u)
    ax[0].grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")  
    ax[0].set_ylabel("X (m)")

    # Subplot 2 (Middle / Y Axis)
    ax[1].plot(x, y1Vector[:,1], label="Desired", lw=lw)
    ax[1].plot(x, y2Vector[:,1], label="Real", lw=lw)
    ax[1].set_xlim(xlim_l, xlim_u)
    ax[1].grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")  
    ax[1].set_ylabel("Y (m)")

    # Subplot 3 (Bottom / Z Axis)
    ax[2].plot(x, y1Vector[:,2], label="Desired", lw=lw)
    ax[2].plot(x, y2Vector[:,2], label="Real", lw=lw)
    ax[2].set_xlim(xlim_l, xlim_u)
    ax[2].grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")  
    ax[2].set_ylabel("Z (m)")



trajectory_v2 = PlotTemplate()



with trajectory_v2.figure(
    xlabel="Time (s)", 
    ylabel="Meters (m)", 
    #figsize=(8, 10),            # Increased height so 3 subplots aren't squished
    legend=True,
    save = "ObjectTrajecory.png",
    legend_loc="upper left",
    title="Trajectory", 
    #nrows=1,
    font_name="Roboto",
    dpi=600,
    font_size=16                # Slightly smaller font size works better with 3 subplots
) as (fig, ax):

    # Subplot 1 (Top / X Axis)
    ax.plot(x, y2Vector[:,0], label="X (m)", lw=lw)
    ax.plot(x, y2Vector[:,1], label="Y (m)", lw=lw)
    ax.plot(x, y2Vector[:,2], label="Z (m)", lw=lw)
    ax.set_xlim(xlim_l, xlim_u)
    ax.grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")

# %% [markdown]
# # Mechanical power
#
# required to move or lift a robot, use
#
# $$P = \tau \times \dot q$$

# %%
power = np.sum(RigtArmIn_tau * RigtArmOut_dq, axis=1)
exp2_power = np.sum(exp2_RigtArmIn_tau * exp2_RigtArmOut_dq, axis=1)



# Crop experiment 1
mask1 = (time >= xlim_l) & (time <= xlim_u)

cropped_time = time[mask1]
cropped_power = np.abs(power)[mask1]

# Crop experiment 2
mask2 = (exp2_time >= xlim_l) & (exp2_time <= xlim_u)

exp2_cropped_time = exp2_time[mask2]
exp2_cropped_power = np.abs(exp2_power)[mask2]

# %% [markdown]
# # analysis

# %%
import pandas as pd
import numpy as np

def compute_stats(power, time):
    energy = np.trapezoid(power, time)
    return {
        "RMS": np.sqrt(np.mean(power**2)),
        "Std": np.std(power),
        "Peak": np.max(power),
        "Min": np.min(power),
        "Energy": energy,
    }

results = {
    "Force On Demand": compute_stats(cropped_power, cropped_time),
    "Constant Contact Forces": compute_stats(exp2_cropped_power, exp2_cropped_time),
}

df = pd.DataFrame(results).T
metrics = df.columns.tolist()

baseline = "Force On Demand"
other = "Constant Contact Forces"

reduction = {m: (df.loc[baseline, m] - df.loc[other, m]) / df.loc[baseline, m] * 100
             for m in metrics}

def fmt_cell(value, red=None):
    if red is None:
        return f"{value:.2f}"
    sign = "-" if red >= 0 else "+"
    return rf"\makecell{{{value:.2f} \\ \scriptsize({sign}{abs(red):.1f}\%)}}"

row_baseline = " & ".join(fmt_cell(df.loc[baseline, m]) for m in metrics)
row_other = " & ".join(fmt_cell(df.loc[other, m], reduction[m]) for m in metrics)

latex = rf"""
\begin{{table}}[htbp]
\caption{{Comparison of Power Statistics and Absorbed Energy}}
\label{{tab:power_statistics}}
\centering
\small
\setlength{{\tabcolsep}}{{3pt}}
\begin{{tabular}}{{|c|c|c|c|c|c|}}
\hline
\textbf{{Experiment}} & \multicolumn{{4}}{{c|}}{{\textbf{{Power Statistics [W]}}}} & \textbf{{Energy [J]}} \\
\cline{{2-5}}
 & \textit{{RMS}} & \textit{{Std}} & \textit{{Peak}} & \textit{{Min}} &  \\
\hline
{baseline} & {row_baseline} \\
\hline
{other} & {row_other} \\
\hline
\multicolumn{{6}}{{l}}{{\scriptsize Values in parentheses: \% reduction relative to Force On Demand.}}
\end{{tabular}}
\end{{table}}
"""
print(latex)
# Out:
# \begin{table}[htbp]
# \caption{Comparison of Power Statistics and Absorbed Energy}
# \label{tab:power_statistics}
# \centering
# \small
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# \textbf{Experiment} & \multicolumn{4}{c|}{\textbf{Power Statistics [W]}} & \textbf{Energy [J]} \\
# \cline{2-5}
#  & \textit{RMS} & \textit{Std} & \textit{Peak} & \textit{Min} &  \\
# \hline
# Force On Demand & 12.21 & 2.63 & 15.36 & 6.11 & 1168.53 \\
# \hline
# Constant Contact Forces & \makecell{14.09 \\ \scriptsize(+15.4\%)} & \makecell{2.65 \\ \scriptsize(+0.5\%)} & \makecell{17.90 \\ \scriptsize(+16.5\%)} & \makecell{6.66 \\ \scriptsize(+8.9\%)} & \makecell{1355.90 \\ \scriptsize(+16.0\%)} \\
# \hline
# \multicolumn{6}{l}{\scriptsize Values in parentheses: \% reduction relative to Force On Demand.}
# \end{tabular}
# \end{table}

# %%
import numpy as np

def alpha(x, L, k):
    z = np.clip(x / L, 0.0, 1.0)
    return 0.5 * (1.0 - np.cos(np.pi * z**k))


L = 0.8
x = np.linspace(0, 1, 500)

k_values = np.array([0.5, 1, 2, 4])

ys = np.array([
    0.5 * (1.0 - np.cos(np.pi * np.clip(x / L, 0.0, 1.0)**k))
    for k in k_values
])


cosine = PlotTemplate()

with cosine.figure(
    xlabel="Velocity (m/s)", 
    ylabel=r"Activation $\alpha$" ,
    #figsize=(8, 10),            # Increased height so 3 subplots aren't squished
    legend=True,
    save = "Activation.png",
    legend_loc="upper left",
    title="Raised Cosine Activation Function", 
    #nrows=1,
    font_name="Roboto",
    dpi=600,
    font_size=16                # Slightly smaller font size works better with 3 subplots
) as (fig, ax):

    # Subplot 1 (Top / X Axis)
    ax.plot(x, ys[0], label=f"k = {k_values[0]}", lw=lw)
    ax.plot(x, ys[1], label=f"k = {k_values[1]}", lw=lw)
    ax.plot(x, ys[2], label=f"k = {k_values[2]}", lw=lw)
    ax.plot(x, ys[3], label=f"k = {k_values[3]}", lw=lw)
    ax.axvline(L, color="black", linestyle="--", linewidth=1.5)

    # Add δ as an x-axis tick
    ax.set_xlim(0, 1)
    xticks = list(ax.get_xticks())
    xticks.append(L)
    xticks = sorted(set(xticks))

    xticklabels = []
    for t in xticks:
        if np.isclose(t, L):
            xticklabels.append(r"$\delta$")
        else:
            xticklabels.append(f"{t:g}")

    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels)
    ax.grid(True, linestyle="--", alpha=0.4, color="#CCCCCC")
